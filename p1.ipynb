# %% [markdown]
# 1. Escreva um programa que leia um número e verifique se é ou não um número primo.

# %%
num = int(input("Digite um número: "))

if num <= 1:
    print(f"{num} não é número primo!")
else:
    primo = True
    for n in range(2, num):
        if num % n == 0:
            primo = False
            break
    
    if primo:
        print(f'{num} é um número primo!')
    else:
        print(f'{num} não é um número primo!')

# %% [markdown]
# 2. Escreva um programa para controlar uma pequena máquina registradora. Você deve solicitar ao usuário que digite o código do produto e a quantidade desejada. Utilize a tabela de códigos a seguir para obter o preço de cada produto.

# %%
print('Olá, seja bem-vindo a Máquina Registradora! Solicite o produto em base ao código dele:')
print('- 1 : R$ 0.50 \n- 2 : R$ 1.00 \n- 3 : R$ 4.00 \n- 4 : R$ 7.00 \n- 5 : R$ 8.00')
print('\nPara finalizar a compra, digite 0!')

armazemCompras = 0
limiteProduto = 5
x = 0

while True:
    x += 1
    codigoProduto = int(input('Insira o código do produto > '))

    if codigoProduto == 0:
            break
    
    match codigoProduto:
         case 1:
            preco = 0.50
         case 2:
            preco = 1.00
         case 3:
            preco = 4.00
         case 4:
            preco = 7.00
         case 5:
            preco = 8.00
         case _:
            print('Insira o número do código do produto corretamente. Tente novamente!')

    quantidadeProduto = int(input('Insira a quantidade de produtos > '))

    subtotal = preco * quantidadeProduto 
    armazemCompras += subtotal

    print(f"Compra {x} - Subtotal adicionado: R$ {subtotal:.2f}")
print(f"Total da compra: R$ {armazemCompras:.2f}")

# %% [markdown]
# 3. Você deve desenvolver um programa para acompanhar a pontuação de um time no Campeonato Brasileiro de Futebol rodada por rodada.

# %%
inserirTime = input('Insira o nome do time no Campeonato Brasileiro de Futebol > ')

rodada = 1
vitoria = 0
pontos = 0 
empate = 0
derrota = 0

while True:
    print(f'\n = RODADA {rodada} =')
    print('Adicione aqui a pontuação em base:')
    print('- 1. Vitória (+3p) \n- 2. Empate (+1p) \n- 3. Derrota (0p) \n- 0. Para encerrar o programa')
    escolha = int(input('Insira o número para sua escolha > '))

    if escolha == 0:
        break

    match escolha:
        case 1:
            vitoria += 3
            pontos += 1
            print('\nDessa vez foi vitória! +3 pontos')

            placar = input('Insira quanto foi o jogo > ')
            print(f'O placar do jogo foi {placar}!')
            
        case 2:
            empate += 1
            pontos += 1
            print('\nEmpate. +1 pontos')

            placar = input('Insira quanto foi o jogo > ')
            print(f'O placar do jogo foi {placar}!')
        case 3:
            derrota += 1
            print('\nInfelizmente foi derrota.. 0 pontos')

            placar = input('Insira quanto foi o jogo > ')
            print(f'O placar do jogo foi {placar}!')
        case _: 
            print('Insira o número da sua escolha corretamente, releia a lista!')

    print(f"Pontos atuais: {pontos}")
    rodada += 1

if pontos > 20:
   classificado = 'Libertadores'
elif pontos > 15:
  classificado = 'Sul Americana'
else:
   classificado = 'Rebaixamento'

print(f'\n= RESULTADO EM SI =')
print(f'Time: {inserirTime} - Pontuação: {pontos}')
print(f'- Vitórias: {vitoria} \n- Empate: {empate} \n- Derrota: {derrota} \n- Status de classificação: {classificado}')

# %% [markdown]
# 4. Crie um programa.

# %%
# Loja virtual da Pichau focada na comercialização de computadores, monitores, periféricos e muito mais.
# Este programa simula a compra de PCs com opção de desconto dependendo da forma de pagamento.

# Mensagem de informação base
print('= INFORMAÇÕES SOBRE O ALUNO =')
print('Nome: Gabriel Philippe Souza da Silva')
print('RA: 2028736')
print('Turma: 1º Ano - ADS')
print('Disciplina: Pensamento Computacional e Lógica em Python\n')

# Mensagem de boas-vindas e informações iniciais
print('🛒: Seja bem-vindo(a) à Pichau! Loja virtual focada na comercialização de computadores, monitores, periféricos e muito mais! Aproveite nossas promoções!')
print('⚠️: IMPORTANTE: É possível ressaltar que o limite de compra no momento é de 5 itens por categoria, devido as normas de segurança!')
print('0. Encerrar compras e ir ao pagamento\n1. Computadores\n2. Monitores\n3. Periféricos\n4. Cadeiras Gamer')

# Inicialização de variáveis para controle das compras
comprasArmazem = 0  # Armazena o valor total das compras
numeroCompras = 1  # Contador para número de compras ao carrinho

# Loop principal do programa
while True:
    # Solicita ao usuário que escolha uma categoria ou encerre (0)
    decisaoCategoria = int(input('Escolha uma das categorias abaixo para começar suas compras (lembre-se, para prosseguir o pagamento digite 0) > '))

    # Verifica se o usuário escolheu 0, sai do loop
    if decisaoCategoria == 0:
        break

    # Estrutura match-case para lidar com as diferentes categorias
    match decisaoCategoria:
        case 1:  # Categoria de Computadores
            print('\n= COMPUTADORES =')
            print('1. PC Gamer Pichau Lynx AMD Ryzen 5 + GTX 1660 - R$ 3999\n2. PC Gamer Pichau Templar i5 + RTX 3060 - R$ 5299\n3. PC Pichau Office Intel i3 12ª Geração - R$ 2299\n4. PC Gamer Pichau Drakkar R5 + RX 6600 XT - R$ 4799')
            escolha = int(input('Escolha o código do computador > '))
            match escolha: # Define o preço conforme o computador escolhido
                case 1: preco_produto = 3999; nomeItem = 'PC Gamer Pichau Lynx AMD Ryzen 5 + GTX 1660'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 2: preco_produto = 5299; nomeItem = 'PC Gamer Pichau Templar i5 + RTX 3060'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 3: preco_produto = 2299; nomeItem = 'PC Pichau Office Intel i3 12ª Geração'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 4: preco_produto = 4799; nomeItem = 'PC Gamer Pichau Drakkar R5 + RX 6600 XT'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case _:  # Caso inválido
                    print('Opção inválida! Tente novamente.')
                    break
            
        case 2:  # Categoria de Periféricos
            print('\n= PERIFÉRICOS =')
            print('1. Teclado Mecânico Pichau XFire RGB - R$ 199\n2. Mouse Gamer Pichau Hive 60 RGB - R$ 129\n3. Headset Pichau Mirage 7.1 - R$ 249\n4. Mousepad Pichau Control XL - R$ 59')
            escolha = int(input('Escolha o código do periférico > '))
            match escolha:  # Define o preço conforme o periférico escolhido
                case 1: preco_produto = 199; nomeItem = 'Teclado Mecânico Pichau XFire RGB'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 2: preco_produto = 129; nomeItem = 'Mouse Gamer Pichau Hive 60 RGB'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 3: preco_produto = 249; nomeItem = 'Headset Pichau Mirage 7.1'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 4: preco_produto = 59; nomeItem = 'Mousepad Pichau Control XL'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case _:
                    print('Opção inválida! Tente novamente.')
                    break

        case 3:  # Categoria de Monitores
            print('\n= MONITORES =')
            print('1. Pichau Tempest 27" 165Hz Full HD IPS - R$ 999\n2. Pichau Tempest 24" 144Hz LED - R$ 899\n3. Pichau Viper 32" 165Hz Curvo VA - R$ 1399\n4. Pichau Hawk 27" 75Hz IPS - R$ 749')
            escolha = int(input('Escolha o código do monitor > '))
            match escolha:  # Define o preço conforme o monitor escolhido
                case 1: preco_produto = 999; nomeItem = 'Pichau Tempest 27" 165Hz Full HD IPS'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 2: preco_produto = 899; nomeItem = 'Pichau Tempest 24" 144Hz LED'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 3: preco_produto = 1399; nomeItem = 'Pichau Viper 32" 165Hz Curvo VA'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 4: preco_produto = 749; nomeItem = 'Pichau Hawk 27" 75Hz IPS'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case _:
                    print('Opção inválida! Tente novamente.')
                    break

        case 4:  # Categoria de Cadeiras
            print('\n= CADEIRAS =')
            print('1. Cadeira Gamer Pichau Phantom - R$ 899\n2. Cadeira Pichau Elite Comfort - R$ 1099\n3. Cadeira Ergonomica Pichau Storm - R$ 999\n4. Cadeira Pichau Alpha Mesh - R$ 799')
            escolha = int(input('Escolha o código da cadeira > '))
            match escolha: # Define o preço conforme a cadeira escolhido
                case 1: preco_produto = 899; nomeItem = 'Cadeira Gamer Pichau Phantom'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 2: preco_produto = 1099; nomeItem = 'Cadeira Pichau Elite Comfort'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 3: preco_produto = 999; nomeItem = 'Cadeira Ergonomica Pichau Storm'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case 4: preco_produto = 799; nomeItem = 'Cadeira Pichau Alpha Mesh'; quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))
                case _:
                    print('Opção inválida! Tente novamente.')
                    break

        case _:  # Caso o usuário digite uma opção inválida de categoria
            print('Insira corretamente o número das opções informadas!')
            break

    # Verifica se a quantidade está dentro do limite permitido
    if quantidadeProdutos < 1 or quantidadeProdutos > 5:
        print('\nPor favor, mantenha-se dentro das normas de segurança! Você só pode escolher de 1 a 5 produtos por categoria!')
        break
        
    # Calcula o subtotal e adiciona ao total das compras
    subtotal = preco_produto * quantidadeProdutos
    comprasArmazem += subtotal

    # Mostra informações da compra atual
    print('\n= CHECKOUT =')
    print(f'- Compra {numeroCompras} - Subtotal adicionado ao carrinho: R$ {subtotal:.2f}')
    print(f'- Nome do item comprado: {nomeItem}\n- Preço do item: {preco_produto} reais\n- Quantidade do produto: {quantidadeProdutos}')
    numeroCompras += 1  # Incrementa o contador de compras

prosseguirPagamento = input('Você deseja prosseguir ao pagamento? (sim ou não) > ')    

if prosseguirPagamento.lower() == 'sim':
    if comprasArmazem == 0:
        # Verifica se houve compras antes de prosseguir para o pagamento
        print('\n⚠️: Nenhuma compra foi realizada, você DEVE selecionar algum produto com alguma quantidade maior que 0. Tente novamente!')
    else:
        # Mostra opções de pagamento
        print('\n= FORMAS DE PAGAMENTO =')
        print('⚠️: IMPORTANTE: Alguns descontos somente são aplicados com compras acima de R$ 1000!')
        print('1. PIX (15% de desconto)\n2. Cartão de Crédito/Débito (sem desconto)\n3. Boleto Bancário (10% de desconto)')

        # Solicita a forma de pagamento
        pagamento = int(input('Escolha a forma de pagamento (1, 2 ou 3) > '))

        # Verifica as condições para aplicar descontos
        if (pagamento == 1 or pagamento == 3) and comprasArmazem > 1000:
            if pagamento == 1:  # PIX com 15% de desconto
                certeza = input('Você TEM certeza que deseja pagar com esse método? > (sim ou não) ')

                if certeza.lower() == "sim":
                    totalFinal = comprasArmazem - (comprasArmazem * 0.15)
                    print(f'\n✅: Pagamento via PIX realizado com sucesso. Desconto de 15% aplicado!')
                    print(f'- Total sem desconto: R$ {comprasArmazem:.2f}')
                    print(f'- Total com desconto: R$ {totalFinal:.2f}')
                elif certeza.lower() == "não":
                    print('❌: Compra cancelada! Pagamento não realizado.')
                else:
                    print('❌: Opção inválida! Tente novamente.')
            elif pagamento == 3:  # Boleto com 10% de desconto
                certeza = input('Você TEM certeza que deseja pagar com esse método? > (sim ou não) ')

                if certeza.lower() == "sim":
                    totalFinal = comprasArmazem - (comprasArmazem * 0.10)
                    print(f'\nPagamento via Boleto realizado com sucesso. Desconto de 10% aplicado!')
                    print(f'- Total sem desconto: R$ {comprasArmazem:.2f}')
                    print(f'- Total com desconto: R$ {totalFinal:.2f}')
                elif certeza.lower() == "não":
                    print('✅: Pagamento cancelado! Compra não realizada.')
                else:
                    print('❌: Opção inválida! Tente novamente.')
        elif pagamento == 1 or pagamento == 3:  # Pagamento com PIX/Boleto mas valor < 1000
            print('\n✅: Compra realizada com sucesso! O desconto só é válido para compras acima de R$ 1000. ')
            print(f'Total: R$ {comprasArmazem:.2f}')
        elif pagamento == 2:  # Cartão sem desconto
            print(f'\n✅: Compra via Cartão realizado com sucesso!')
            print(f'- Total sem desconto: R$ {comprasArmazem:.2f}')
        else:  # Opção de pagamento inválida
            print('\n❌: Opção inválida! Cancelando processo.. tente novamente!')
elif prosseguirPagamento.lower() == 'não':
    print('✅: Certamente, pagamento cancelado com sucesso!')
else:
    print('❌: Opção inválida! Tente novamente.')

# Eu acho que mereço 4/4. Devido ao fato que eu estruturei e adicionei todos os conceitos atuais realizado em classe corretamente, tive o conhecimento de atribuir totalmente o funcionamento do Python na prática e nunca dei trabalho em classe, então conforme esses pontos, eu mereço.
