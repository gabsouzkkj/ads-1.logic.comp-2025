# %% [markdown]
# 1. Escreva um programa que leia um número e verifique se é ou não um número primo.

# %%
numero = int(input('Insira um número para verificação de número primo > '))

for
# Out:
# Ele é um número primo!

# %% [markdown]
# 2. Escreva um programa para controlar uma pequena máquina registradora. Você deve solicitar ao usuário que digite o código do produto e a quantidade desejada. Utilize a tabela de códigos a seguir para obter o preço de cada produto.

# %%
print('Olá, seja bem-vindo a Máquina Registradora! Solicite o produto em base ao código dele:')
print('- 1 : R$ 0.50 \n- 2 : R$ 1.00 \n- 3 : R$ 4.00 \n- 4 : R$ 7.00 \n- 5 : R$ 8.00')
print('\nPara finalizar a compra, digite 0!')

armazemCompras = 0
limiteProduto = 5
x = 0

while True:
    x += 1
    codigoProduto = int(input('Insira o código do produto > '))

    if codigoProduto == 0:
            break
    
    match codigoProduto:
         case 1:
            preco = 0.50
         case 2:
            preco = 1.00
         case 3:
            preco = 4.00
         case 4:
            preco = 7.00
         case 5:
            preco = 8.00
         case _:
            print('Insira o número do código do produto corretamente. Tente novamente!')

    quantidadeProduto = int(input('Insira a quantidade de produtos > '))

    subtotal = preco * quantidadeProduto 
    armazemCompras += subtotal

    print(f"Compra {x} - Subtotal adicionado: R$ {subtotal:.2f}")

print(f"Total da compra: R$ {armazemCompras:.2f}")
# Out:
# Olá, seja bem-vindo a Máquina Registradora! Solicite o produto em base ao código dele:
# - 1 : R$ 0.50
# - 2 : R$ 1.00
# - 3 : R$ 4.00
# - 4 : R$ 7.00
# - 5 : R$ 8.00
#
# Para finalizar a compra, digite 0!
# Compra 1 - Subtotal adicionado: R$ 10.00
# Compra 2 - Subtotal adicionado: R$ 10.00
# Compra 3 - Subtotal adicionado: R$ 10.00
# Total da compra: R$ 30.00

# %% [markdown]
# 3. Você deve desenvolver um programa para acompanhar a pontuação de um time no Campeonato Brasileiro de Futebol rodada por rodada.

# %%
inserirTime = input('Insira o nome do time no Campeonato Brasileiro de Futebol > ')

rodada = 1
vitoria = 0
pontos = 0 
empate = 0
derrota = 0

while True:
    print(f'\n = RODADA {rodada} =')
    print('Adicione aqui a pontuação em base:')
    print('- 1. Vitória (+3p) \n- 2. Empate (+1p) \n- 3. Derrota (0p) \n- 0. Para encerrar o programa')
    escolha = int(input('Insira o número para sua escolha > '))

    if escolha == 0:
        break

    match escolha:
        case 1:
            vitoria += 3
            pontos += 1
            print('\nDessa vez foi vitória! +3 pontos')

            placar = input('Insira quanto foi o jogo > ')
            print(f'O placar do jogo foi {placar}!')
            
        case 2:
            empate += 1
            pontos += 1
            print('\nEmpate. +1 pontos')

            placar = input('Insira quanto foi o jogo > ')
            print(f'O placar do jogo foi {placar}!')
        case 3:
            derrota += 1
            print('\nInfelizmente foi derrota.. 0 pontos')

            placar = input('Insira quanto foi o jogo > ')
            print(f'O placar do jogo foi {placar}!')
        case _: 
            print('Insira o número da sua escolha corretamente, releia a lista!')

    print(f"Pontos atuais: {pontos}")
    rodada += 1

if pontos > 20:
   classificado = 'Libertadores'
elif pontos > 15:
  classificado = 'Sul Americana'
else:
   classificado = 'Rebaixamento'

print(f'\n= RESULTADO EM SI =')
print(f'Time: {inserirTime} - Pontuação: {pontos}')
print(f'- Vitórias: {vitoria} \n- Empate: {empate} \n- Derrota: {derrota} \n- Status de classificação: {classificado}')
# Out:
#  = RODADA 1 =
# Adicione aqui a pontuação em base:
# - 1. Vitória (+3p)
# - 2. Empate (+1p)
# - 3. Derrota (0p)
# - 0. Para encerrar o programa
#
# Dessa vez foi vitória! +3 pontos
# O placar do jogo foi 3x0!
# Pontos atuais: 1
#
#  = RODADA 2 =
# Adicione aqui a pontuação em base:
# - 1. Vitória (+3p)
# - 2. Empate (+1p)
# - 3. Derrota (0p)
# - 0. Para encerrar o programa
#
# Empate. +1 pontos
# O placar do jogo foi 1x1!
# Pontos atuais: 2
#
#  = RODADA 3 =
# Adicione aqui a pontuação em base:
# - 1. Vitória (+3p)
# - 2. Empate (+1p)
# - 3. Derrota (0p)
# - 0. Para encerrar o programa
#
# Infelizmente foi derrota.. 0 pontos
# O placar do jogo foi 0x0!
# Pontos atuais: 2
#
#  = RODADA 4 =
# Adicione aqui a pontuação em base:
# - 1. Vitória (+3p)
# - 2. Empate (+1p)
# - 3. Derrota (0p)
# - 0. Para encerrar o programa
#
# Dessa vez foi vitória! +3 pontos
# O placar do jogo foi 1x0!
# Pontos atuais: 3
#
#  = RODADA 5 =
# Adicione aqui a pontuação em base:
# - 1. Vitória (+3p)
# ...

# %% [markdown]
# 4. Crie um programa.

# %%
# Loja virtual da Pichau focada na comercialização de computadores, montiores, periféricos e muito mais.
# Este programa simula a compra de PCs com opção de desconto dependendo da forma de pagamento.

print('Seja bem-vindo(a) à Pichau! Loja virtual focada na comercialização de computadores, montiores, periféricos e muito mais! Aproveite nossas promoções!\n')
print('IMPORTANTE: É possível ressaltar que o limite de compra no momento é de 5 itens por categoria, devido as normas de segurança!')
print('0. Encerrar o programa o prosseguir para o pagamento\n1. Computadores\n2. Monitores\n3. Periféricos\n4. Cadeiras Gamer')

compras = 0
compraN = 1

while True:
    decisaoCategoria = int(input('Escolha uma das categorias abaixo para começar suas compras (lembre-se, para prosseguir o pagamento digite 0) > '))

    if decisaoCategoria == 0:
        break

    match decisaoCategoria:
        case 1:
            print('\n= COMPUTADORES =')
            print('1. PC Gamer Pichau Lynx AMD Ryzen 5 + GTX 1660 - R$ 3999\n2. PC Gamer Pichau Templar i5 + RTX 3060 - R$ 5299\n3. PC Pichau Office Intel i3 12ª Geração - R$ 2299\n4. PC Gamer Pichau Drakkar R5 + RX 6600 XT - R$ 4799')
            escolha = int(input('Escolha o código do computador > '))
            match escolha:
                case 1: precoComputador = 3999
                case 2: precoComputador = 5299
                case 3: precoComputador = 2299
                case 4: precoComputador = 4799
                case _: 
                    print('Opção inválida! Tente novamente.')
                    break

        case 2:
            print('\n= PERIFÉRICOS =')
            print('1. Teclado Mecânico Pichau XFire RGB - R$ 199\n2. Mouse Gamer Pichau Hive 60 RGB - R$ 129\n3. Headset Pichau Mirage 7.1 - R$ 249\n4. Mousepad Pichau Control XL - R$ 59')
            escolha = int(input('Escolha o código do periférico > '))
            match escolha:
                case 1: item =precoComputador = 199
                case 2: precoComputador = 129
                case 3: precoComputador = 249
                case 4: precoComputador = 59
                case _:
                    print('Opção inválida! Tente novamente.')
                    break

        case 3:
            print('\n= MONITORES =')
            print('1. Pichau Tempest 27" 165Hz Full HD IPS - R$ 999\n2. Pichau Tempest 24" 144Hz LED - R$ 899\n3. Pichau Viper 32" 165Hz Curvo VA - R$ 1399\n4. Pichau Hawk 27" 75Hz IPS - R$ 749')
            escolha = int(input('Escolha o código do monitor > '))
            match escolha:
                case 1: precoComputador = 999
                case 2: precoComputador = 899
                case 3: precoComputador = 1399
                case 4: precoComputador = 749
                case _:
                    print('Opção inválida! Tente novamente.')
                    break
        case 4:
            print('\n= CADEIRAS =')
            print('1. Cadeira Gamer Pichau Phantom - R$ 899\n2. Cadeira Pichau Elite Comfort - R$ 1099\n3. Cadeira Ergonomica Pichau Storm - R$ 999\n4. Cadeira Pichau Alpha Mesh - R$ 799')
            escolha = int(input('Escolha o código da cadeira > '))
            match escolha:
                case 1: precoComputador = 899
                case 2: precoComputador = 1099
                case 3: precoComputador = 999
                case 4: precoComputador = 799
                case _:
                    print('Opção inválida! Tente novamente.')
                    break
        case _:
            print('Insira corretamente o número das opções informadas!')
            break

    quantidadeProdutos = int(input('Insira a quantidade de produtos que deseja > '))

    if quantidadeProdutos >= 10:
        print('\nPor favor, mantenha-se dentro das diretrizes de segurança! Você só pode escolher 5 produtos por categoria!')
        break

    subtotal = precoComputador * quantidadeProdutos
    compras += subtotal

    print(f'\nCompra {compraN} - Subtotal adicionado ao carrinho: R$ {subtotal:.2f}')
    compraN += 1

    print('\nFormas de pagamento disponíveis:')
    print('* IMPORTANTE: Alguns descontos somente são aplicados com compras acima de R$ 1000!')
    print('1. PIX (15% de desconto)\n2. Cartão de Crédito/Débito (sem desconto)\n3. Boleto Bancário (10% de desconto)')

    pagamento = int(input('Escolha a forma de pagamento (1, 2 ou 3) > '))

    if pagamento == 1 or pagamento == 3 and compras > 1000:
        if pagamento == 1:
            totalFinal = compras - (compras * 0.15)
            print(f'\nPagamento via PIX selecionado. Desconto de 15% aplicado!')
            print(f'Total sem desconto: R$ {compras:.2f}')
            print(f'Total com desconto: R$ {totalFinal:.2f}')
        elif pagamento == 3:
            totalFinal = compras - (compras * 0.10)
            print(f'\nPagamento via Boleto selecionado. Desconto de 10% aplicado!')
            print(f'Total sem desconto: R$ {compras:.2f}')
            print(f'Total com desconto: R$ {totalFinal:.2f}')
    elif pagamento == 1 or pagamento == 3:
        print('\nO desconto só é válido para compras acima de R$ 1000.')
        print(f'A sua compra ficou: R$ {compras:.2f}')
    elif pagamento == 2:
        print(f'\nPagamento via Cartão selecionado. Total sem desconto: R$ {compras:.2f}')
    else:
        print('\nOpção inválida! Considerando pagamento sem desconto.')
        print(f'Total: R$ {compras:.2f}')
# Out:
# Seja bem-vindo(a) à Pichau! Loja virtual focada na comercialização de computadores, montiores, periféricos e muito mais! Aproveite nossas promoções!
#
# IMPORTANTE: É possível ressaltar que o limite de compra no momento é de 5 itens, devido aos termos de segurança!
# 0. Encerrar o programa e prosseguir para o pagamento
# 1. Computadores
# 2. Monitores
# 3. Periféricos
# 4. Cadeiras Gamer
#
# = COMPUTADORES =
# 1. PC Gamer Pichau Lynx AMD Ryzen 5 + GTX 1660 - R$ 3999
# 2. PC Gamer Pichau Templar i5 + RTX 3060 - R$ 5299
# 3. PC Pichau Office Intel i3 12ª Geração - R$ 2299
# 4. PC Gamer Pichau Drakkar R5 + RX 6600 XT - R$ 4799
# Por favor, mantenha-se dentro das diretrizes de segurança! Você só pode escolher 5 produtos por categoria.
